# %% [markdown]
# ## Report: act_report
#
# - The tweet archive of Twitter user @dog_rates (a twitter account that rates people's dogs using humorous coment about the dog) was wrangled, where the data was gathered using different methods, assessed, cleaned and consolidated into one.
# - The clean master data was then stored.
# - Following the wrangling of the daataset, analysis was performed on the cleaned master dataset to find insights and display visualizations based on the wrangled tweet achaive data.
# - The analysis was conducted so that the number of dogs will be counted per dog stage namely: doggo, pupper,floofer and puppo.
#
# - The first analysis was to count the number of dogs per dog_stage and this was achieved by grouping by dog stage column and the following insights were dedued:
#
# 1. The pupper stage has the highest number of dogs of 224
#
# 2. The floofer has the lowest number of dogs being 3
#
# 3. The doggo had 74 number of dogs while the puppo had 29 dogs.
#
# - A bar chat is a useful visualization plot for categorical vatiables.
# - A bar chart was plotted to illustrate the distributions of dogs per dog stage (categorical variable) visually.
# - The visual below shows the distribution per dog stage:
#
# ![image.png](attachment:image.png)
#
# - The second analysis was to find the correlation between the retweets count and favorite count and the following insights were observed:
#
# 1. The correlation between the two variable was 0.88 which is a strong positive linear correlation. This implies that he number of favorites will increase with an increase in the number of retweets and vice versa.
#
# - A scatter plot was used to illustrate the correlation between the two variable visually as scatter plots are best for visualizing relationships.
# - The visual below shows the relationship between the retweets count and favorite count:
#
# ![image-2.png](attachment:image-2.png)
